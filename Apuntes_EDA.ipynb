# %% [markdown]
# <a href="https://colab.research.google.com/github/sergioc248/apuntes-inteligencia-artificial/blob/main/Apuntes_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 123#Variables en python
# Las variables categoricas o text se guardan inicialmente en tipo object. <br>
# Las variables numéricas se guardan en tipo Int o float (8, 16, 32, 64)

# %%
# !python -V
# Out:
# Python 3.11.11

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- -------------------
# absl-py                            1.4.0
# accelerate                         1.3.0
# aiohappyeyeballs                   2.4.6
# aiohttp                            3.11.12
# aiosignal                          1.3.2
# alabaster                          1.0.0
# albucore                           0.0.23
# albumentations                     2.0.4
# ale-py                             0.10.1
# altair                             5.5.0
# annotated-types                    0.7.0
# anyio                              3.7.1
# argon2-cffi                        23.1.0
# argon2-cffi-bindings               21.2.0
# array_record                       0.6.0
# arviz                              0.20.0
# astropy                            7.0.1
# astropy-iers-data                  0.2025.2.10.0.33.26
# astunparse                         1.6.3
# atpublic                           4.1.0
# ...

# %%
# prompt: crear dos listas de numpy, una con 10 nombres inventados y 10 edades también inventadas

import numpy as np

# Crear una lista de 10 nombres inventados
nombres = np.array(['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', 'Grace', 'Heidi', 'Ivan', 'Judy'])

# Crear una lista de 10 edades inventadas
edades = np.array([25, 30, 22, 28, 24, 35, 27, 29, 31, 26])

# Imprimir las listas
print("Nombres:", nombres)
print("Edades:", edades)
# Out:
# Nombres: ['Alice' 'Bob' 'Charlie' 'David' 'Eve' 'Frank' 'Grace' 'Heidi' 'Ivan'
#  'Judy']
# Edades: [25 30 22 28 24 35 27 29 31 26]

# %%
type(nombres)
# Out:
# numpy.ndarray

# %%
# prompt: crear un arreglo (5,2) donde la primera columna sea el valor unitario y la segunda la cantidad

import numpy as np

# Crear un arreglo (5,2)
data = np.array([
    [10, 2],  # Valor unitario: 10, Cantidad: 2
    [5, 5],   # Valor unitario: 5, Cantidad: 5
    [20, 1],  # Valor unitario: 20, Cantidad: 1
    [15, 3],  # Valor unitario: 15, Cantidad: 3
    [8, 4]    # Valor unitario: 8, Cantidad: 4
])

data
# Out:
# array([[10,  2],
#        [ 5,  5],
#        [20,  1],
#        [15,  3],
#        [ 8,  4]])

# %%
# prompt: multiplicar las dos columnas del arreglo arr y agregarla para quedar de la forma (5,3)

# Calculate the product of the two columns and reshape the array
arr = data[:, 0] * data[:, 1]
arr = arr.reshape(5, 1)

# Concatenate the original array with the new column
new_data = np.concatenate((data, arr), axis=1)
new_data
# Out:
# array([[10,  2, 20],
#        [ 5,  5, 25],
#        [20,  1, 20],
#        [15,  3, 45],
#        [ 8,  4, 32]])

# %%
# prompt: calcular el promedio de la columna 0 de arr

# Calculate the average of the first column (index 0) of the 'new_data' array
average_col0 = np.mean(new_data[:, 0])

print("Average of column 0:", average_col0)
# Out:
# Average of column 0: 11.6

# %%
promedio_column1 = np.mean(new_data[:,1])
promedio_column1
# Out:
# 3.0

# %% [markdown]
# El profesor gritó cuando dijo que hacer operaciones con arreglo era usar numpy

# %%
# prompt: creame un dataframe con el nombre, el cargo, el salario y la antiguedad en años, poner 20 filas con datos sintéticos

import pandas as pd
import numpy as np

# Crear datos sintéticos para 20 filas
nombres = np.random.choice(['Alice', 'Bob', 'Charlie', 'David', 'Eve', 'Frank', 'Grace', 'Heidi', 'Ivan', 'Judy'], 20)
cargos = np.random.choice(['Ingeniero', 'Analista', 'Gerente', 'Desarrollador', 'Tester'], 20)
salarios = np.random.randint(30000, 100000, 20)
antiguedades = np.random.randint(1, 10, 20)

# Crear el DataFrame
data = {'Nombre': nombres, 'Cargo': cargos, 'Salario': salarios, 'Antiguedad': antiguedades}
df = pd.DataFrame(data)

# Mostrar el DataFrame
df
# Out:
#    Nombre          Cargo  Salario  Antiguedad
# 0    Judy         Tester    38536           1
# 1     Bob         Tester    37409           6
# 2   Grace  Desarrollador    79853           7
# 3   David       Analista    88261           7
# 4    Judy         Tester    59529           3
# 5     Eve       Analista    30756           3
# 6     Eve  Desarrollador    77438           1
# 7   Frank         Tester    93256           1
# 8    Judy        Gerente    60940           6
# 9    Judy  Desarrollador    62452           7
# 10  Heidi      Ingeniero    44948           3
# 11  Grace         Tester    88617           4
# 12    Bob         Tester    55925           3
# 13    Eve        Gerente    42284           3
# 14  Alice      Ingeniero    49105           4
# 15    Bob      Ingeniero    42108           6
# 16    Bob  Desarrollador    52332           9
# 17    Bob         Tester    42388           2
# 18  David      Ingeniero    83439           5
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Numpy maneja arreglos (solo númericos), Pandas maneja dataframes (numéricos, texto, etc)

# %%
df.Salario.mean()
# Out:
# 60340.65

# %%
df.Cargo.unique()
# Out:
# array(['Tester', 'Desarrollador', 'Analista', 'Gerente', 'Ingeniero'],
#       dtype=object)

# %%
cantidad = df.Cargo.value_counts()
cantidad
# Out:
# Cargo
# Tester           8
# Desarrollador    4
# Ingeniero        4
# Analista         2
# Gerente          2
# Name: count, dtype: int64

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Salario'}>,
#         <Axes: title={'center': 'Antiguedad'}>]], dtype=object)

# %%
df.describe()
# Out:
#             Salario  Antiguedad
# count     20.000000   20.000000
# mean   60340.650000    4.400000
# std    19820.510563    2.370876
# min    30756.000000    1.000000
# 25%    42362.000000    3.000000
# 50%    57727.000000    4.000000
# 75%    78041.750000    6.250000
# max    93256.000000    9.000000

# %%
df.describe().T
# Out:
#             count      mean           std      min      25%      50%  \
# Salario      20.0  60340.65  19820.510563  30756.0  42362.0  57727.0
# Antiguedad   20.0      4.40      2.370876      1.0      3.0      4.0
#
#                  75%      max
# Salario     78041.75  93256.0
# Antiguedad      6.25      9.0

# %% [markdown]
# ### Pandas asigna el tipo de variable de una columna observando las primeras 100 filas.
# Por ejemplo, si una columna tiene 100 datos numéricos, y en la fila 200 tiene una letra, ese valor será NaN (not a number). <br>
# Si otra columna tiene 99 datos numéricos y en la 100 una letra, su tipo de variable será Object (por ser texto).

# %%
df.describe(include="object")
# Out:
#        Nombre   Cargo
# count      20      20
# unique      8       5
# top       Bob  Tester
# freq        5       8

# %%
df.Salario.plot(kind="pie", title="Salario", figsize=(5,5), autopct="%1.1f%%", legend=True)
# Out:
# <Axes: title={'center': 'Salario'}, ylabel='Salario'>

# %%
# !pip install squarify

# %%
import matplotlib.pyplot as plt
import squarify

#Treemap
squarify.plot(sizes = df.Salario, label = df.Nombre, alpha=.8)
plt.axis('off')
plt.show()

# %%
# prompt: creame un dataframe ocn datos sintéticos de clientes (nombre, longitud, latitud, valor compras) la longitud y la latitud que sean cercanas a bucaramanga

import pandas as pd
import numpy as np

# Latitud y longitud cercanas a Bucaramanga
latitud_bucaramanga = 7.125
longitud_bucaramanga = -73.119

# Crear datos sintéticos
num_clientes = 100
nombres = ['Cliente ' + str(i) for i in range(1, num_clientes + 1)]
longitudes = np.random.normal(loc=longitud_bucaramanga, scale=0.1, size=num_clientes)
latitudes = np.random.normal(loc=latitud_bucaramanga, scale=0.1, size=num_clientes)
valor_compras = np.random.randint(10000, 500000, num_clientes)

# Crear el DataFrame
df_clientes = pd.DataFrame({
    'Nombre': nombres,
    'Longitud': longitudes,
    'Latitud': latitudes,
    'Valor_Compras': valor_compras
})

# Mostrar las primeras filas del DataFrame
print(df_clientes.head())
# Out:
#       Nombre   Longitud   Latitud  Valor_Compras
# 0  Cliente 1 -73.186682  6.960908         254599
# 1  Cliente 2 -73.215656  7.172346         254955
# 2  Cliente 3 -73.112970  7.266320         252845
# 3  Cliente 4 -72.955138  7.156849          33942
# 4  Cliente 5 -73.009984  7.161832         387944

# %%
import plotly.express as px

fig = px.scatter_mapbox(df_clientes, lat="Latitud", lon="Longitud", size=["Valor_Compras"])
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-b931de0fb982> in <cell line: 0>()
#       1 import plotly.express as px
#       2
# ----> 3 fig = px.scatter_mapbox(df_clientes, lat="Latitud", lon="Longitud", size=["Valor_Compras"])
#       4 fig.show()
#
# /usr/local/lib/python3.11/dist-packages/plotly/express/_chart_types.py in scatter_mapbox(data_frame, lat, lon, color, text, hover_name, hover_data, custom_data, size, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, opacity, size_max, zoom, center, mapbox_style, title, template, width, height)
#    1392     symbol mark on a Mapbox map.
#    1393     """
# -> 1394     return make_figure(args=locals(), constructor=go.Scattermapbox)
#    1395
#    1396
#
# ...

# %%
import plotly.express as px

# Use the 'Valor_Compras' column directly for the 'size' argument
fig = px.scatter_mapbox(df_clientes, lat="Latitud", lon="Longitud", size="Valor_Compras")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Los dataframe en pandas se construyen a partir de un diccionario en python

# %%
import pandas as pd
import numpy as np

# Crear un dataset simulado
np.random.seed(42)
data = {
    "Estudiante": [f"E{i}" for i in range(1, 21)],
    "Edad": np.random.randint(18, 25, size=20),
    "Género": np.random.choice(["Femenino", "Masculino"], size=20),
    "Nota_Matemáticas": np.random.normal(70, 10, size=20).round(1),
    "Nota_Ciencias": np.random.normal(75, 12, size=20).round(1),
    "Nota_Inglés": np.random.normal(65, 15, size=20).round(1),
}

# %%
df = pd.DataFrame(data)

# Mostrar el dataset
df.head()

# %%
df.tail(3)

# %%
df.dtypes

# %% [markdown]
# ### Puedo leer dataframes de enlaces

# %%
clientes = pd.read_csv("https://raw.githubusercontent.com/adiacla/bigdata/refs/heads/master/Churn_Modelling.csv")
clientes.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender   Age  \
# 0          1    15634602  Hargrave          619    France  Female  42.0
# 1          1    15634602  Hargrave          619    France  Female  42.0
# 2          2    15647311      Hill          608     Spain     NaN  41.0
# 3          3    15619304      Onio          502    France  Female  42.0
# 4          4    15701354      Boni          699    France  Female  39.0
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       2       0.00              1          1               1
# 2       1   83807.86             25          0               1
# 3       8  159660.80              3          1               0
# 4       1       0.00              2          0               0
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        101348.88       1
# 2        112542.58       0
# 3        113931.57       1
# ...

# %%
clientes.shape
# Out:
# (10002, 14)

# %%
clientes.drop(["RowNumber",'CustomerId', 'Surname'], axis=1, inplace=True)

# %%
clientes.columns
# Out:
# Index(['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Exited'],
#       dtype='object')

# %% [markdown]
# #EDA es Exploratory Data Analysis
# Debemos analizar los datos para que nos cuenten una historia

# %% [markdown]
# * describe() hace un análisis descriptivo de los valores **numéricos** por default

# %%
clientes.describe()
# Out:
#         CreditScore          Age        Tenure        Balance  NumOfProducts  \
# count  10002.000000  9997.000000  10002.000000   10002.000000   10002.000000
# mean     650.522196    38.922977      5.012298   76484.905248       1.532593
# std       96.644765    10.488788      2.892112   62399.411918       0.627175
# min      350.000000    18.000000      0.000000       0.000000       1.000000
# 25%      584.000000    32.000000      3.000000       0.000000       1.000000
# 50%      652.000000    37.000000      5.000000   97198.540000       1.000000
# 75%      717.750000    44.000000      7.000000  127647.840000       2.000000
# max      850.000000    92.000000     10.000000  250898.090000      25.000000
#
#           HasCrCard  IsActiveMember  EstimatedSalary        Exited
# count  10002.000000    10002.000000     10002.000000  10002.000000
# mean       0.705459        0.515197    100086.790137      0.203759
# std        0.455859        0.499794     57505.855282      0.402812
# ...

# %%
clientes.describe(include="object")
# Out:
#        Geography Gender
# count      10002  10001
# unique         3      2
# top       France   Male
# freq        5015   5458

# %% [markdown]
# ### Ejemplo con dataset de estudiantes

# %%
# Crear un dataset simulado
np.random.seed(42)
data = {
    "Estudiante": [f"E{i}" for i in range(1, 21)],
    "Edad": np.random.randint(18, 25, size=20),
    "Género": np.random.choice(["Femenino", "Masculino"], size=20),
    "Nota_Matemáticas": np.random.normal(70, 10, size=20).round(1),
    "Nota_Ciencias": np.random.normal(75, 12, size=20).round(1),
    "Nota_Inglés": np.random.normal(65, 15, size=20).round(1),
}
df = pd.DataFrame(data)
df
# Out:
#    Estudiante  Edad     Género  Nota_Matemáticas  Nota_Ciencias  Nota_Inglés
# 0          E1    24  Masculino              72.2           69.5         41.6
# 1          E2    21  Masculino              62.3           75.8         53.1
# 2          E3    22  Masculino              71.4           72.9         79.0
# 3          E4    24  Masculino              69.7           89.4         75.2
# 4          E5    20  Masculino              81.3           83.4         75.5
# 5          E6    22   Femenino              69.0           72.9         67.6
# 6          E7    22   Femenino              64.7           64.1         74.9
# 7          E8    24  Masculino              89.1           89.3         68.6
# 8          E9    19  Masculino              49.7           84.4         62.5
# 9         E10    20  Masculino              81.2          106.9         82.5
# 10        E11    24   Femenino              77.8           78.2         61.3
# ...

# %%
df.describe(include="object")
# Out:
#        Estudiante     Género
# count          20         20
# unique         20          2
# top            E1  Masculino
# freq            1         12

# %% [markdown]
# ## <font color="cyan"> El profesor gritó: Las columnas que tienen todos sus datos únicos no sirven para predecir y se deben eliminar.

# %%
df.Género.value_counts()
# Out:
# Género
# Masculino    12
# Femenino      8
# Name: count, dtype: int64

# %%
contarGeneros = df.Género.value_counts()
total = contarGeneros.values.sum()
hombresperc = contarGeneros["Masculino"] / total * 100
mujeresperc = contarGeneros["Femenino"] / total * 100

print(f"% de Hombres: {hombresperc} \n% de Mujeres: {mujeresperc}")
# Out:
# % de Hombres: 60.0
#  % de Mujeres: 40.0

# %%
contarGeneros.plot(kind="pie", title="Género", figsize=(5,5), autopct="%1.1f%%", colors=["c", "lightcoral"], legend=True)
# Out:
# <Axes: title={'center': 'Género'}, ylabel='count'>

# %% [markdown]
# ## <font color="cyan"> El profesor gritó: Si entre clases hay diferencias mayores al 30%, los datos están desbalanceados. Hay que buscar una estrategia para balancear.

# %% [markdown]
# La feature desbalanceada puede ser droppeada o se generan datos sintéticos para balancear la muestra. En Inteligencia Artificial, la suma de los datos no importa, importa la varianza entre ellos.

# %% [markdown]
# ###¿Qué es la cardinalidad de género? R// Los valores que puede tomar la feature género.

# %%
df["Género"].unique()
# Out:
# array(['Masculino', 'Femenino'], dtype=object)

# %% [markdown]
# ### Manipulación de datos a través del dataframe

# %%
df.describe(include="float").T["50%"]["Nota_Ciencias"]
# Es lo mismo que
df.Nota_Ciencias.median()
# Out:
# 75.9

# %% [markdown]
# ## <font color="blue">Visualizaciones

# %% [markdown]
# Los gráficos de barras sirven para datos númericos y de clase. Los histogramas solo sirven para datos númericos

# %% [markdown]
# Debo utilizar
#
# ```
# plt.show()
# ```
# entre cada gráfica para no sobreescribirlas

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Histograma de edades
sns.histplot(df['Edad'], bins=7, kde=True, color='aqua')
plt.title("Distribución de Edad")
plt.show()

# %% [markdown]
# <font color="yellow"> Debo utilizar un número de bines que permita que cada clase en el histograma tenga datos

# %%
sns.histplot(df['Edad'], bins=5, kde=True, color='aqua')
plt.title("Distribución de Edad")
plt.show()

# %%
# Gráfico de dispersión: Nota_Matemáticas vs Nota_Ciencias
sns.scatterplot(x="Nota_Matemáticas", y="Nota_Ciencias", hue="Género", data=df)
plt.title("Relación entre Matemáticas y Ciencias")
plt.show()

# Boxplot de notas por género
sns.boxplot(x="Género", y="Nota_Matemáticas", data=df)
plt.title("Distribución de Notas de Matemáticas por Género")
plt.show()
